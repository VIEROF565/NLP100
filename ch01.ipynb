# %% [markdown]
# # 第一章　準備運動

# %% [markdown]
# ## 00.文字列の逆順

# %%
a="stressed"
b=a[::-1]
print(b)
# Out:
# desserts

# %% [markdown]
# ## 01.「パタトクカシーー」

# %%
a="パタトクカシーー"
b=a[0::2]
print(b)
# Out:
# パトカー

# %% [markdown]
# ## 02.「パトカー」+「タクシー」=「パタトクカシーー」

# %%
str1="パトカー"
str2="タクシー"
ans=""
for k1,k2 in zip(str1,str2):
    ans+= (k1+k2)
    
print(ans)
# Out:
# パタトクカシーー

# %% [markdown]
# ## 03.円周率

# %%
str1="Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics."
str_list=str1.split(" ")
print(str_list)
# Out:
# ['Now', 'I', 'need', 'a', 'drink,', 'alcoholic', 'of', 'course,', 'after', 'the', 'heavy', 'lectures', 'involving', 'quantum', 'mechanics.']

# %% [markdown]
# ## 04.元素記号

# %%
string="Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can."
str_list=string.split(" ")
cl=[1,5,6,7,8,9,15,16,19]
dictionary={}

for k,strs in enumerate(str_list):
    if k+1 in cl:
        dictionary[strs[0:1]]=k+1
    else:
        dictionary[strs[0:2]]=k+1
    
print(dictionary)
# Out:
# {'H': 1, 'He': 2, 'Li': 3, 'Be': 4, 'B': 5, 'C': 6, 'N': 7, 'O': 8, 'F': 9, 'Ne': 10, 'Na': 11, 'Mi': 12, 'Al': 13, 'Si': 14, 'P': 15, 'S': 16, 'Cl': 17, 'Ar': 18, 'K': 19, 'Ca': 20}

# %% [markdown]
# ## 05. n-gram

# %%
def ngram (string,t):
    length= len(string)
    gram=[]
    for k in range(length-t+1):
        gram.append(string[k:t+k])
    return gram
        
nlper="I am an NLPer"
nlper_list = nlper.split(" ")

print("単語b-gram",ngram(nlper_list,2))
print("文字bi-gram",ngram(nlper,2))
# Out:
# 単語b-gram [['I', 'am'], ['am', 'an'], ['an', 'NLPer']]
# 文字bi-gram ['I ', ' a', 'am', 'm ', ' a', 'an', 'n ', ' N', 'NL', 'LP', 'Pe', 'er']

# %% [markdown]
# ## 06.集合

# %%
str1="paraparaparadise"
str2 = "paragraph"
X_list = ngram(str1,2)
Y_list = ngram(str2,2)

X = set(X_list)
Y = set(Y_list)
print("X:",X)
print("Y:",Y)
print("和集合:",X|Y)
print("積集合",X&Y)
print("差集合",X-Y)

if 'se' in X:
    print("seはXに入ってる！！！")
else:
    print("seはXに入ってない！！！")
if 'se' in Y:
    print("seはYに入ってる！！！")
else:
    print("seはYに入ってない！！！")
# Out:
# X: {'ad', 'ap', 'di', 'se', 'pa', 'is', 'ra', 'ar'}
# Y: {'ap', 'ph', 'ag', 'pa', 'gr', 'ra', 'ar'}
# 和集合: {'ad', 'ap', 'ph', 'di', 'ag', 'se', 'pa', 'is', 'gr', 'ra', 'ar'}
# 積集合 {'ra', 'pa', 'ap', 'ar'}
# 差集合 {'se', 'is', 'di', 'ad'}
# seはXに入ってる！！！
# seはYに入ってない！！！

# %% [markdown]
# ## 07.テンプレートによる文生成

# %%
def temperture(x,y,z):
    return "{}時の{}は{}".format(x,y,z)


temperture(x=12,y="気温",z=22.4)
# Out:
# '12時の気温は22.4'

# %% [markdown]
# ## 08.暗号文

# %%
def cipher(string):
    ret_str=""
    for str1 in string:
        k=ord(str1)
        if 97 <=  k<=122:
            ret_str+= str(k)
        else:
            ret_str+=str1
    return ret_str
        
a=cipher("RuuChanKawaii")
print(a)
# Out:
# R117117C10497110K9711997105105

# %% [markdown]
# ## 09. Typoglycemia

# %%
import random  

k="Banner Ruu AnkaK Kapibara Takuro Vier"
k_list = k.split(" ")
new_list = []
for strs in k_list :
    if len(strs) <= 4:
        new_list.append(strs)
    else:
        ret=list(strs[1:-1])
        random.shuffle(ret)
        newstr=strs[0]+''.join(ret)+strs[-1]
        new_list.append(newstr)
        
print(new_list)
# Out:
# ['Banner', 'Ruu', 'AkanK', 'Karbpiaa', 'Takruo', 'Vier']
